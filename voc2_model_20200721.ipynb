# %%
import pandas as pd

# %%
from aicentro.session import Session
session = Session(verify=False)

# %%
import tensorflow as tf
import numpy as np
from tensorflow.python import keras
from tensorflow.python.keras.datasets import mnist
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Dropout
from tensorflow.python.keras import regularizers
from tensorflow.python.keras.optimizers import RMSprop

# %%
voc_df = pd.read_csv('/aihub/data/vocdata_result_20200715.csv', encoding = 'EUCKR')

# %%
voc_df.dtypes
# Out:
# 상담대분류       int64
# 상담중분류       int64
# 상담소분류       int64
# 상담일자        int64
# 상품구분        int64
# 시군구         int64
# 영업단         int64
# 급지          int64
# 최초개통일       int64
# 해지일        object
# AS신청유형      int64
# AS원인유형      int64
# AS처리유형      int64
# AS접수일자    float64
# AS완료일자    float64
# AS처리시간     object
# dtype: object

# %%
voc_df
# Out:
#        상담대분류  상담중분류  상담소분류      상담일자  상품구분  시군구  영업단  급지     최초개통일       해지일  \
# 0          4     10     27  20160101     0    9    0   3  20101005  20160615
# 1          4     10     27  20160101     0   94    0   4  20121214  20151231
# 2          4     10     27  20160101     0   30    2   2  20140120       NaN
# 3          2     11     56  20160101     1   55    2   1  20150916       NaN
# 4          4     10     27  20160102     0  239    1   3  20101006       NaN
# ...      ...    ...    ...       ...   ...  ...  ...  ..       ...       ...
# 40483      2     18     53  20200714     1   70    0   4  20190404       NaN
# 40484      2     18     40  20200714     1   47    2   2  20191119       NaN
# 40485      3      6     47  20200714     1  219    1   3  20200409       NaN
# 40486      2     18     54  20200714     1  249    1   6  20200411       NaN
# 40487      2     18     53  20200714     1  178    0   3  20200418       NaN
#
#        AS신청유형  AS원인유형  AS처리유형      AS접수일자      AS완료일자 AS처리시간
# 0          25      86      68         NaN         NaN    NaN
# 1          25      86      68         NaN         NaN    NaN
# 2          25      86      68         NaN         NaN    NaN
# 3          18      75      55  20160103.0  20160104.0     16
# 4          25      86      68         NaN         NaN    NaN
# ...       ...     ...     ...         ...         ...    ...
# 40483      25      86      68         NaN         NaN    NaN
# 40484      25      86      68         NaN         NaN    NaN
# 40485      25      86      68         NaN         NaN    NaN
# 40486      25      86      68         NaN         NaN    NaN
# 40487      25      86      68         NaN         NaN    NaN
#
# [40488 rows x 16 columns]

# %%
voc_df['해지일']=voc_df['해지일'].replace(np.nan, 19990101)
voc_df['해지일']=voc_df['해지일'].replace('@', 19990101)

# %%
voc_df
# Out:
#        상담대분류  상담중분류  상담소분류      상담일자  상품구분  시군구  영업단  급지     최초개통일       해지일  \
# 0          4     10     27  20160101     0    9    0   3  20101005  20160615
# 1          4     10     27  20160101     0   94    0   4  20121214  20151231
# 2          4     10     27  20160101     0   30    2   2  20140120  19990101
# 3          2     11     56  20160101     1   55    2   1  20150916  19990101
# 4          4     10     27  20160102     0  239    1   3  20101006  19990101
# ...      ...    ...    ...       ...   ...  ...  ...  ..       ...       ...
# 40483      2     18     53  20200714     1   70    0   4  20190404  19990101
# 40484      2     18     40  20200714     1   47    2   2  20191119  19990101
# 40485      3      6     47  20200714     1  219    1   3  20200409  19990101
# 40486      2     18     54  20200714     1  249    1   6  20200411  19990101
# 40487      2     18     53  20200714     1  178    0   3  20200418  19990101
#
#        AS신청유형  AS원인유형  AS처리유형      AS접수일자      AS완료일자 AS처리시간
# 0          25      86      68         NaN         NaN    NaN
# 1          25      86      68         NaN         NaN    NaN
# 2          25      86      68         NaN         NaN    NaN
# 3          18      75      55  20160103.0  20160104.0     16
# 4          25      86      68         NaN         NaN    NaN
# ...       ...     ...     ...         ...         ...    ...
# 40483      25      86      68         NaN         NaN    NaN
# 40484      25      86      68         NaN         NaN    NaN
# 40485      25      86      68         NaN         NaN    NaN
# 40486      25      86      68         NaN         NaN    NaN
# 40487      25      86      68         NaN         NaN    NaN
#
# [40488 rows x 16 columns]

# %%
voc_df['해지일'] = voc_df['해지일'].astype(str).astype(int)

# %%
voc_df['AS처리시간']=voc_df['AS처리시간'].replace(np.nan, -1)

# %%
voc_df
# Out:
#        상담대분류  상담중분류  상담소분류      상담일자  상품구분  시군구  영업단  급지     최초개통일       해지일  \
# 0          4     10     27  20160101     0    9    0   3  20101005  20160615
# 1          4     10     27  20160101     0   94    0   4  20121214  20151231
# 2          4     10     27  20160101     0   30    2   2  20140120  19990101
# 3          2     11     56  20160101     1   55    2   1  20150916  19990101
# 4          4     10     27  20160102     0  239    1   3  20101006  19990101
# ...      ...    ...    ...       ...   ...  ...  ...  ..       ...       ...
# 40483      2     18     53  20200714     1   70    0   4  20190404  19990101
# 40484      2     18     40  20200714     1   47    2   2  20191119  19990101
# 40485      3      6     47  20200714     1  219    1   3  20200409  19990101
# 40486      2     18     54  20200714     1  249    1   6  20200411  19990101
# 40487      2     18     53  20200714     1  178    0   3  20200418  19990101
#
#        AS신청유형  AS원인유형  AS처리유형      AS접수일자      AS완료일자 AS처리시간
# 0          25      86      68         NaN         NaN     -1
# 1          25      86      68         NaN         NaN     -1
# 2          25      86      68         NaN         NaN     -1
# 3          18      75      55  20160103.0  20160104.0     16
# 4          25      86      68         NaN         NaN     -1
# ...       ...     ...     ...         ...         ...    ...
# 40483      25      86      68         NaN         NaN     -1
# 40484      25      86      68         NaN         NaN     -1
# 40485      25      86      68         NaN         NaN     -1
# 40486      25      86      68         NaN         NaN     -1
# 40487      25      86      68         NaN         NaN     -1
#
# [40488 rows x 16 columns]

# %%
val_columns = ['상담대분류', '상담중분류', '상담소분류', '상담일자', '상품구분', '급지', '해지일', 'AS신청유형', 'AS원인유형', 'AS처리유형', 'AS처리시간']
voc_df = pd.DataFrame(voc_df, columns=val_columns)

# %%
voc_df
# Out:
#        상담대분류  상담중분류  상담소분류      상담일자  상품구분  급지       해지일  AS신청유형  AS원인유형  \
# 0          4     10     27  20160101     0   3  20160615      25      86
# 1          4     10     27  20160101     0   4  20151231      25      86
# 2          4     10     27  20160101     0   2        -1      25      86
# 3          2     11     56  20160101     1   1        -1      18      75
# 4          4     10     27  20160102     0   3        -1      25      86
# ...      ...    ...    ...       ...   ...  ..       ...     ...     ...
# 40483      2     18     53  20200714     1   4        -1      25      86
# 40484      2     18     40  20200714     1   2        -1      25      86
# 40485      3      6     47  20200714     1   3        -1      25      86
# 40486      2     18     54  20200714     1   6        -1      25      86
# 40487      2     18     53  20200714     1   3        -1      25      86
#
#        AS처리유형 AS처리시간
# 0          68     -1
# 1          68     -1
# 2          68     -1
# 3          55     16
# 4          68     -1
# ...       ...    ...
# 40483      68     -1
# 40484      68     -1
# 40485      68     -1
# 40486      68     -1
# 40487      68     -1
#
# [40488 rows x 11 columns]

# %%
voc_df['상담일자']=pd.to_datetime(voc_df['상담일자'],format='%Y%m%d')

# %%
voc_df['해지일']=pd.to_datetime(voc_df['해지일'],format='%Y%m%d')

# %%
voc_df.dtypes
# Out:
# 상담대분류              int64
# 상담중분류              int64
# 상담소분류              int64
# 상담일자      datetime64[ns]
# 상품구분               int64
# 시군구                int64
# 영업단                int64
# 급지                 int64
# 최초개통일              int64
# 해지일       datetime64[ns]
# AS신청유형             int64
# AS원인유형             int64
# AS처리유형             int64
# AS접수일자           float64
# AS완료일자           float64
# AS처리시간            object
# dtype: object

# %%
voc_df['해지일'] = voc_df['해지일'].replace(to_replace=np.nan, value=29991231)

# %%
voc_df
# Out:
#        상담대분류  상담중분류  상담소분류       상담일자  상품구분  시군구  영업단  급지     최초개통일  \
# 0          4     10     27 2016-01-01     0    9    0   3  20101005
# 1          4     10     27 2016-01-01     0   94    0   4  20121214
# 2          4     10     27 2016-01-01     0   30    2   2  20140120
# 3          2     11     56 2016-01-01     1   55    2   1  20150916
# 4          4     10     27 2016-01-02     0  239    1   3  20101006
# ...      ...    ...    ...        ...   ...  ...  ...  ..       ...
# 40483      2     18     53 2020-07-14     1   70    0   4  20190404
# 40484      2     18     40 2020-07-14     1   47    2   2  20191119
# 40485      3      6     47 2020-07-14     1  219    1   3  20200409
# 40486      2     18     54 2020-07-14     1  249    1   6  20200411
# 40487      2     18     53 2020-07-14     1  178    0   3  20200418
#
#              해지일  AS신청유형  AS원인유형  AS처리유형      AS접수일자      AS완료일자 AS처리시간
# 0     2016-06-15      25      86      68         NaN         NaN     -1
# 1     2015-12-31      25      86      68         NaN         NaN     -1
# 2     1999-01-01      25      86      68         NaN         NaN     -1
# 3     1999-01-01      18      75      55  20160103.0  20160104.0     16
# 4     1999-01-01      25      86      68         NaN         NaN     -1
# ...          ...     ...     ...     ...         ...         ...    ...
# 40483 1999-01-01      25      86      68         NaN         NaN     -1
# 40484 1999-01-01      25      86      68         NaN         NaN     -1
# 40485 1999-01-01      25      86      68         NaN         NaN     -1
# 40486 1999-01-01      25      86      68         NaN         NaN     -1
# 40487 1999-01-01      25      86      68         NaN         NaN     -1
#
# [40488 rows x 16 columns]

# %%
val_columns = ['상담대분류', '상담중분류', '상담소분류', '상담일자', '상품구분', '급지', '해지일', 'AS신청유형', 'AS원인유형', 'AS처리유형', 'AS처리시간']
voc_df = pd.DataFrame(voc_df, columns=val_columns)

# %%
voc_df
# Out:
#        상담대분류  상담중분류  상담소분류       상담일자  상품구분  급지        해지일  AS신청유형  AS원인유형  \
# 0          4     10     27 2016-01-01     0   3 2016-06-15      25      86
# 1          4     10     27 2016-01-01     0   4 2015-12-31      25      86
# 2          4     10     27 2016-01-01     0   2 1999-01-01      25      86
# 3          2     11     56 2016-01-01     1   1 1999-01-01      18      75
# 4          4     10     27 2016-01-02     0   3 1999-01-01      25      86
# ...      ...    ...    ...        ...   ...  ..        ...     ...     ...
# 40483      2     18     53 2020-07-14     1   4 1999-01-01      25      86
# 40484      2     18     40 2020-07-14     1   2 1999-01-01      25      86
# 40485      3      6     47 2020-07-14     1   3 1999-01-01      25      86
# 40486      2     18     54 2020-07-14     1   6 1999-01-01      25      86
# 40487      2     18     53 2020-07-14     1   3 1999-01-01      25      86
#
#        AS처리유형 AS처리시간
# 0          68     -1
# 1          68     -1
# 2          68     -1
# 3          55     16
# 4          68     -1
# ...       ...    ...
# 40483      68     -1
# 40484      68     -1
# 40485      68     -1
# 40486      68     -1
# 40487      68     -1
#
# [40488 rows x 11 columns]

# %%
voc_df['cnslt_rscs_diff'] = (voc_df['해지일'] - voc_df['상담일자'])

# %%
voc_df
# Out:
#        상담대분류  상담중분류  상담소분류       상담일자  상품구분  급지        해지일  AS신청유형  AS원인유형  \
# 0          4     10     27 2016-01-01     0   3 2016-06-15      25      86
# 1          4     10     27 2016-01-01     0   4 2015-12-31      25      86
# 2          4     10     27 2016-01-01     0   2 1999-01-01      25      86
# 3          2     11     56 2016-01-01     1   1 1999-01-01      18      75
# 4          4     10     27 2016-01-02     0   3 1999-01-01      25      86
# ...      ...    ...    ...        ...   ...  ..        ...     ...     ...
# 40483      2     18     53 2020-07-14     1   4 1999-01-01      25      86
# 40484      2     18     40 2020-07-14     1   2 1999-01-01      25      86
# 40485      3      6     47 2020-07-14     1   3 1999-01-01      25      86
# 40486      2     18     54 2020-07-14     1   6 1999-01-01      25      86
# 40487      2     18     53 2020-07-14     1   3 1999-01-01      25      86
#
#        AS처리유형 AS처리시간 cnslt_rscs_diff
# 0          68     -1        166 days
# 1          68     -1         -1 days
# 2          68     -1      -6209 days
# 3          55     16      -6209 days
# 4          68     -1      -6210 days
# ...       ...    ...             ...
# 40483      68     -1      -7865 days
# 40484      68     -1      -7865 days
# 40485      68     -1      -7865 days
# 40486      68     -1      -7865 days
# 40487      68     -1      -7865 days
#
# [40488 rows x 12 columns]

# %%
import datetime
dt = datetime.datetime.now()

# %%
voc_df['cnslt_rscs_diff'] = voc_df['cnslt_rscs_diff'].dt.days

# %%
voc_df
# Out:
#        상담대분류  상담중분류  상담소분류       상담일자  상품구분  급지        해지일  AS신청유형  AS원인유형  \
# 0          4     10     27 2016-01-01     0   3 2016-06-15      25      86
# 1          4     10     27 2016-01-01     0   4 2015-12-31      25      86
# 2          4     10     27 2016-01-01     0   2 1999-01-01      25      86
# 3          2     11     56 2016-01-01     1   1 1999-01-01      18      75
# 4          4     10     27 2016-01-02     0   3 1999-01-01      25      86
# ...      ...    ...    ...        ...   ...  ..        ...     ...     ...
# 40483      2     18     53 2020-07-14     1   4 1999-01-01      25      86
# 40484      2     18     40 2020-07-14     1   2 1999-01-01      25      86
# 40485      3      6     47 2020-07-14     1   3 1999-01-01      25      86
# 40486      2     18     54 2020-07-14     1   6 1999-01-01      25      86
# 40487      2     18     53 2020-07-14     1   3 1999-01-01      25      86
#
#        AS처리유형 AS처리시간  cnslt_rscs_diff
# 0          68     -1              166
# 1          68     -1               -1
# 2          68     -1            -6209
# 3          55     16            -6209
# 4          68     -1            -6210
# ...       ...    ...              ...
# 40483      68     -1            -7865
# 40484      68     -1            -7865
# 40485      68     -1            -7865
# 40486      68     -1            -7865
# 40487      68     -1            -7865
#
# [40488 rows x 12 columns]

# %%
voc_df.dtypes
# Out:
# 상담대분류                       int64
# 상담중분류                       int64
# 상담소분류                       int64
# 상담일자               datetime64[ns]
# 상품구분                        int64
# 급지                          int64
# 해지일                datetime64[ns]
# AS신청유형                      int64
# AS원인유형                      int64
# AS처리유형                      int64
# AS처리시간                     object
# cnslt_rscs_diff             int64
# dtype: object

# %%
voc_df['rscs_yn'] = ( 0 <voc_df['cnslt_rscs_diff'] ) & (voc_df['cnslt_rscs_diff'] < 60)

# %%
voc_df
# Out:
#        상담대분류  상담중분류  상담소분류       상담일자  상품구분  급지        해지일  AS신청유형  AS원인유형  \
# 0          4     10     27 2016-01-01     0   3 2016-06-15      25      86
# 1          4     10     27 2016-01-01     0   4 2015-12-31      25      86
# 2          4     10     27 2016-01-01     0   2 1999-01-01      25      86
# 3          2     11     56 2016-01-01     1   1 1999-01-01      18      75
# 4          4     10     27 2016-01-02     0   3 1999-01-01      25      86
# ...      ...    ...    ...        ...   ...  ..        ...     ...     ...
# 40483      2     18     53 2020-07-14     1   4 1999-01-01      25      86
# 40484      2     18     40 2020-07-14     1   2 1999-01-01      25      86
# 40485      3      6     47 2020-07-14     1   3 1999-01-01      25      86
# 40486      2     18     54 2020-07-14     1   6 1999-01-01      25      86
# 40487      2     18     53 2020-07-14     1   3 1999-01-01      25      86
#
#        AS처리유형 AS처리시간  cnslt_rscs_diff  rscs_yn
# 0          68     -1              166    False
# 1          68     -1               -1    False
# 2          68     -1            -6209    False
# 3          55     16            -6209    False
# 4          68     -1            -6210    False
# ...       ...    ...              ...      ...
# 40483      68     -1            -7865    False
# 40484      68     -1            -7865    False
# 40485      68     -1            -7865    False
# 40486      68     -1            -7865    False
# 40487      68     -1            -7865    False
#
# [40488 rows x 13 columns]

# %%
voc_df.p.to_csv('voc_preScale_final_20200721.csv')

# %%
voc_df_model = pd.read_csv('voc_preScale_final_20200721.csv',encoding='UTF-8')

# %%
voc_df_model
# Out:
#        Unnamed: 0  상담대분류  상담중분류  상담소분류        상담일자  상품구분  급지         해지일  \
# 0               0      4     10     27  2016-01-01     0   3  2016-06-15
# 1               1      4     10     27  2016-01-01     0   4  2015-12-31
# 2               2      4     10     27  2016-01-01     0   2  1999-01-01
# 3               3      2     11     56  2016-01-01     1   1  1999-01-01
# 4               4      4     10     27  2016-01-02     0   3  1999-01-01
# ...           ...    ...    ...    ...         ...   ...  ..         ...
# 40483       40483      2     18     53  2020-07-14     1   4  1999-01-01
# 40484       40484      2     18     40  2020-07-14     1   2  1999-01-01
# 40485       40485      3      6     47  2020-07-14     1   3  1999-01-01
# 40486       40486      2     18     54  2020-07-14     1   6  1999-01-01
# 40487       40487      2     18     53  2020-07-14     1   3  1999-01-01
#
#        AS신청유형  AS원인유형  AS처리유형 AS처리시간
# 0          25      86      68     -1
# 1          25      86      68     -1
# 2          25      86      68     -1
# 3          18      75      55     16
# 4          25      86      68     -1
# ...       ...     ...     ...    ...
# 40483      25      86      68     -1
# 40484      25      86      68     -1
# 40485      25      86      68     -1
# 40486      25      86      68     -1
# 40487      25      86      68     -1
#
# [40488 rows x 12 columns]

# %%
nvoc_df['cnslt_rscs_diff'] = nvoc_df['cnslt_rscs_diff'].dt.days
